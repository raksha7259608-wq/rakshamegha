# %% [markdown]
# <a href="https://colab.research.google.com/github/raksha7259608-wq/rakshamegha/blob/main/experiment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cars_df=pd.read_csv("mtcars.xls")
cars_df
plt.scatter(cars_df['mpg'],cars_df['wt'],marker='*')
plt.xlabel("MPG")
plt.ylabel("Weight")
plt.title('Relationship between the Weight of the carand MPG')
plt.show()
